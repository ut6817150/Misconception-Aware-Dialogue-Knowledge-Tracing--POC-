# %% [markdown]
# # Annotation test run (validation set)
#
# Runs a small LLM annotation test against the human validation gold: five
# validation dialogues, all prompt templates, one model. Logic lives in
# `extension/scripts/` (`prompt_loader`, `extraction`, `scoring`). Every call
# caches per dialogue to `extension/artifacts/extraction_cache/{split}/{model}/{prompt}/{id}.json`
# and re-runs skip valid entries. No output-token cap is set; models use their
# provider defaults, and realised cost is measured from OpenRouter usage
# accounting per call.
#
# **Before running:** `export OPENROUTER_API_KEY=...` in the launching terminal.

# %%
import os, sys
from pathlib import Path
_here = Path.cwd()
for _c in [_here, *_here.parents]:
    if (_c / "extension" / "artifacts").exists():
        os.chdir(_c); break
sys.path.insert(0, str(Path.cwd()))
print("cwd:", os.getcwd(), "| key set:", bool(os.environ.get("OPENROUTER_API_KEY")))
# Out:
# cwd: /Users/tandon.utsav2/Desktop/Experiment_1 | key set: True

# %%
from extension.scripts.load_annotation_data import load_dataset
from extension.scripts import prompt_loader, extraction, scoring

gold = load_dataset("extension/artifacts/annotation_dev_and_val_sets/validation_set.csv")
# the validation gold was carved from the MathDial train split and keeps its
# train indices, so its cache lives under the train split: when the full
# train set is annotated later, these 78 dialogues are already done and skip
DIALOGUES = extraction.dialogues_from(gold, split="train")
UNITS = scoring.units_by_dialogue(gold)
print(f"{len(DIALOGUES)} dialogues, {len(gold)} units")
# Out:
# 78 dialogues, 544 units

# %%
TEST_MODEL = 'minimax/minimax-m3'         # any OpenRouter model slug
TEST_PROMPTS = ['P1_full_codebook']       # any subset of prompt stems, e.g.
                                          # ['P1_full_codebook','P2_condensed_codebook',
                                          #  'P3_minimal','P4_condensed_staged']
N_TEST_DIALOGUES = 5
MAX_WORKERS = 5            # parallel in-flight requests; 4-6 is polite to a pinned provider
TEST_PROVIDER = None   # fastest OpenRouter host for Kimi K3; None for free
                          # routing (set None when testing other models unless
                          # you have checked they are served by the named host)

# %%
TEST_DIALOGUES = DIALOGUES[:N_TEST_DIALOGUES]
for _p in TEST_PROMPTS:
    assert _p in prompt_loader.list_prompts(), f"unknown prompt {_p!r}; available: {prompt_loader.list_prompts()}"
print(f"test model: {TEST_MODEL} on dialogues "
      f"{[d['dialogue_id'] for d in TEST_DIALOGUES]} x prompts {TEST_PROMPTS}\n")

import json as _json
test_rows = []
for prompt in TEST_PROMPTS:
    print(f"  {prompt} ({len(TEST_DIALOGUES)} dialogues, {MAX_WORKERS} workers):")
    extraction.generate_annotations(prompt, TEST_MODEL, TEST_DIALOGUES,
                                    provider=TEST_PROVIDER, max_workers=MAX_WORKERS)
    for dlg in TEST_DIALOGUES:
        rec = _json.load(open(extraction.cache_path(TEST_MODEL, prompt,
                                                    dlg['dialogue_id'], dlg['split'])))
        print(f"  {prompt:22s} {dlg['dialogue_id']}: {'ok' if rec['valid'] else 'invalid':8s} "
              f"cost ${rec['cost_usd']:.4f}  latency {rec['latency_s']:.1f}s")
    s = scoring.score_config(gold, TEST_MODEL, prompt,
                             [d['dialogue_id'] for d in TEST_DIALOGUES], n_boot=0,
                             split='train')
    test_rows.append(s)
    print(f"  -> validity {s['valid_rate']:.0%} | macro-F1(P) {s['macro_f1_P']:.3f} "
          f"| alpha {s['alpha']:.3f} | ${s['usd_per_dialogue']:.4f}/dialogue\n")

import pandas as pd
summary = pd.DataFrame(test_rows)[['prompt','valid_rate','macro_f1_P','alpha',
                                   'usd_per_dialogue','latency_s']].round(3)
print(summary.to_string(index=False))
# Out:
# test model: moonshotai/kimi-k3 on dialogues [1, 21, 35, 79, 143, 178, 255, 270, 275, 289, 300, 306, 323, 344, 351, 356, 380, 434, 448, 494, 532, 554, 589, 617, 635, 656, 695, 736, 758, 779, 818, 822, 842, 862, 947, 958, 966, 980, 992, 1026, 1051, 1063, 1071, 1084, 1089, 1107, 1119, 1217, 1221, 1300, 1349, 1421, 1452, 1490, 1519, 1540, 1553, 1555, 1557, 1571, 1615, 1658, 1668, 1717, 1719, 1776, 1780, 1870, 1890, 1916, 1941, 2018, 2164, 2192, 2196, 2202, 2206, 2222] x prompts ['P1_full_codebook']
#
#   P1_full_codebook (78 dialogues, 5 workers):
#   21: cached
#   35: cached
#   1: cached
#   79: cached
#   143: cached
#   270: cached
#   289: cached
#   255: cached
#   178: cached
#   275: cached
#   300: cached
#   306: cached
#   356: cached
#   323: cached
#   380: cached
#   351: cached
#   344: cached
#   434: cached
#   554: cached
#   532: cached
#   494: cached
#   448: cached
#   617: cached
#   589: cached
#   635: cached
#   695: cached
#   656: cached
#   736: cached
#   779: cached
#   842: cached
#   818: cached
#   822: cached
#   862: cached
#   958: cached
#   947: cached
#   966: cached
#   980: cached
#   992: cached
#   1063: cached
#   1071: cached
#   1051: cached
#   1026: cached
#   1089: cached
#   1119: cached
#   1084: cached
#   1107: cached
#   1221: cached
#   1217: cached
#   1349: cached
#   1300: cached
#   1490: cached
#   1452: cached
#   1553: cached
#   1421: cached
#   1519: cached
#   1540: cached
#   1557: cached
#   1571: cached
#   1615: cached
#   1658: cached
#   1668: cached
#   1717: cached
#   1719: cached
#   1555: cached
#   1780: cached
#   1776: cached
#   1890: cached
#   1870: cached
#   1941: cached
#   1916: cached
#   2018: cached
#   2196: cached
#   2192: cached
#   2164: cached
#   2202: cached
#   2222: cached
#   2206: cached
#   758: ok
#   P1_full_codebook       1: ok       cost $0.3364  latency 78.6s
#   P1_full_codebook       21: ok       cost $0.4439  latency 184.0s
#   P1_full_codebook       35: ok       cost $0.1816  latency 35.6s
#   P1_full_codebook       79: ok       cost $0.2865  latency 170.6s
#   P1_full_codebook       143: ok       cost $0.2620  latency 83.1s
#   P1_full_codebook       178: ok       cost $0.3300  latency 220.8s
#   P1_full_codebook       255: ok       cost $0.2819  latency 140.6s
#   P1_full_codebook       270: ok       cost $0.3803  latency 119.2s
#   P1_full_codebook       275: ok       cost $0.8172  latency 462.9s
#   P1_full_codebook       289: ok       cost $0.5940  latency 240.9s
#   P1_full_codebook       300: ok       cost $0.7272  latency 583.3s
#   P1_full_codebook       306: ok       cost $0.7172  latency 332.7s
#   P1_full_codebook       323: ok       cost $0.7384  latency 1197.4s
#   P1_full_codebook       344: ok       cost $0.3580  latency 120.0s
#   P1_full_codebook       351: ok       cost $0.2308  latency 389.7s
#   P1_full_codebook       356: ok       cost $0.3109  latency 97.4s
#   P1_full_codebook       380: ok       cost $0.5066  latency 273.2s
#   P1_full_codebook       434: ok       cost $0.3705  latency 129.9s
#   P1_full_codebook       448: ok       cost $0.3229  latency 193.9s
#   P1_full_codebook       494: ok       cost $0.2126  latency 50.8s
#   P1_full_codebook       532: ok       cost $0.2478  latency 87.6s
#   P1_full_codebook       554: ok       cost $0.3449  latency 233.7s
#   P1_full_codebook       589: ok       cost $0.3604  latency 134.8s
#   P1_full_codebook       617: ok       cost $0.7441  latency 464.8s
#   P1_full_codebook       635: ok       cost $0.4956  latency 206.4s
#   P1_full_codebook       656: ok       cost $0.3497  latency 114.9s
#   P1_full_codebook       695: ok       cost $0.2830  latency 153.3s
#   P1_full_codebook       736: ok       cost $0.6405  latency 479.6s
#   P1_full_codebook       758: ok       cost $0.3941  latency 555.7s
#   P1_full_codebook       779: ok       cost $0.4419  latency 312.4s
#   P1_full_codebook       818: ok       cost $0.4510  latency 117.6s
#   P1_full_codebook       822: ok       cost $0.6104  latency 198.5s
#   P1_full_codebook       842: ok       cost $0.3146  latency 109.2s
#   P1_full_codebook       862: ok       cost $0.7941  latency 269.3s
#   P1_full_codebook       947: ok       cost $0.7268  latency 276.5s
#   P1_full_codebook       958: ok       cost $0.6457  latency 516.6s
#   P1_full_codebook       966: ok       cost $0.5546  latency 386.7s
#   P1_full_codebook       980: ok       cost $0.4115  latency 152.9s
#   P1_full_codebook       992: ok       cost $0.2248  latency 71.4s
#   P1_full_codebook       1026: ok       cost $0.3954  latency 246.0s
#   P1_full_codebook       1051: ok       cost $0.2630  latency 60.8s
#   P1_full_codebook       1063: ok       cost $0.4325  latency 279.9s
#   P1_full_codebook       1071: ok       cost $0.4969  latency 192.9s
#   P1_full_codebook       1084: ok       cost $0.3227  latency 91.6s
#   P1_full_codebook       1089: ok       cost $0.4727  latency 254.3s
#   P1_full_codebook       1107: ok       cost $0.3490  latency 241.5s
#   P1_full_codebook       1119: ok       cost $0.2485  latency 73.0s
#   P1_full_codebook       1217: ok       cost $0.3619  latency 154.7s
#   P1_full_codebook       1221: ok       cost $0.9023  latency 313.8s
#   P1_full_codebook       1300: ok       cost $0.5190  latency 180.7s
#   P1_full_codebook       1349: ok       cost $0.3090  latency 85.9s
#   P1_full_codebook       1421: ok       cost $0.3244  latency 181.2s
#   P1_full_codebook       1452: ok       cost $0.3516  latency 230.1s
#   P1_full_codebook       1490: ok       cost $0.2766  latency 111.6s
#   P1_full_codebook       1519: ok       cost $0.2956  latency 87.1s
#   P1_full_codebook       1540: ok       cost $0.3748  latency 114.1s
#   P1_full_codebook       1553: ok       cost $0.3866  latency 106.9s
#   P1_full_codebook       1555: ok       cost $0.3916  latency 149.0s
#   P1_full_codebook       1557: ok       cost $0.1660  latency 90.2s
#   P1_full_codebook       1571: ok       cost $0.5094  latency 247.3s
#   P1_full_codebook       1615: ok       cost $0.1496  latency 84.9s
#   P1_full_codebook       1658: ok       cost $0.5753  latency 373.2s
#   P1_full_codebook       1668: ok       cost $0.6008  latency 452.5s
#   P1_full_codebook       1717: ok       cost $0.6730  latency 253.2s
#   P1_full_codebook       1719: ok       cost $0.3087  latency 193.5s
#   P1_full_codebook       1776: ok       cost $0.1879  latency 81.4s
#   P1_full_codebook       1780: ok       cost $0.7159  latency 624.8s
#   P1_full_codebook       1870: ok       cost $0.2985  latency 163.7s
#   P1_full_codebook       1890: ok       cost $0.3318  latency 414.6s
#   P1_full_codebook       1916: ok       cost $0.5201  latency 333.2s
#   P1_full_codebook       1941: ok       cost $0.3031  latency 128.8s
#   P1_full_codebook       2018: ok       cost $0.3534  latency 105.4s
#   P1_full_codebook       2164: ok       cost $0.4407  latency 166.8s
#   P1_full_codebook       2192: ok       cost $0.4255  latency 157.5s
#   P1_full_codebook       2196: ok       cost $0.3204  latency 180.5s
#   P1_full_codebook       2202: ok       cost $0.3716  latency 84.9s
#   P1_full_codebook       2206: ok       cost $0.3093  latency 88.5s
#   P1_full_codebook       2222: ok       cost $0.3767  latency 130.9s
#   -> validity 100% | macro-F1(P) 0.588 | alpha 0.650 | $0.4212/dialogue
#
#           prompt  valid_rate  macro_f1_P  alpha  usd_per_dialogue  latency_s
# P1_full_codebook         1.0       0.588   0.65             0.421    223.813

# %% [markdown]
# ### Notes
#
# Prompt files live in `extension/artifacts/annotation_prompts/`; dropping a
# new `P*.md` there adds it to the run automatically. Every attempt is cached
# with its raw output, full reasoning trace, validation errors, and usage,
# so misreadings of the codebook can be diagnosed from the trace, and are
# retried on the next execution. Scores on five dialogues are a plumbing check,
# not a ranking.
